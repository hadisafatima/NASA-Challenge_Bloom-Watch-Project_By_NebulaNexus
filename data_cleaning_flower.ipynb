# %%
import pandas as pd

# %%
file_path = "flower_bloom_dataset.csv"
df = pd.read_csv(file_path)
df.head(25)
# Out:
#        type  properties.id                           properties.Site  \
# 0   Feature            NaN                               Chino Hills
# 1   Feature            NaN           Carrizo Plain National Monument
# 2   Feature            NaN  Antelope Valley California Poppy Reserve
# 3   Feature            0.0                               Red Hills 0
# 4   Feature            1.0                           Golden Valley 1
# 5   Feature            2.0                             Bear Valley 2
# 6   Feature            3.0                           Golden Valley 3
# 7   Feature            4.0                           Golden Valley 4
# 8   Feature            5.0                           Laura Reserve 5
# 9   Feature            6.0                             Bear Valley 6
# 10  Feature            7.0                          Carlsbad Ranch 7
# 11  Feature            8.0                           Laura Reserve 8
# 12  Feature            9.0                             Bear Valley 9
# 13  Feature           10.0                       Sedgwick Reserve 10
# 14  Feature           11.0                         Carlsbad Ranch 11
# 15  Feature           12.0                          Golden Valley 12
# 16  Feature           13.0                          Golden Valley 13
# 17  Feature           14.0                       Sedgwick Reserve 14
# 18  Feature           15.0                          Golden Valley 15
# 19  Feature           16.0                          Laura Reserve 16
# 20  Feature           17.0                          Laura Reserve 17
# 21  Feature           18.0                            Bear Valley 18
# 22  Feature           19.0                         Carlsbad Ranch 19
# 23  Feature           20.0                          Golden Valley 20
# 24  Feature           21.0                          Golden Valley 21
#
#    properties.Type properties.Season  properties.Area geometry.type  \
# 0             Wild            Spring        25382.057  MultiPolygon
# 1             Wild            Spring       354751.514  MultiPolygon
# 2             Wild            Spring        25182.333  MultiPolygon
# 3       Plantation            Summer        14874.759  MultiPolygon
# 4             Wild            Winter       364929.893  MultiPolygon
# 5             Wild            Winter       228192.230  MultiPolygon
# 6       Plantation              Fall       170488.528  MultiPolygon
# 7       Plantation            Spring       379094.253  MultiPolygon
# 8             Wild              Fall       149813.089  MultiPolygon
# 9       Plantation            Winter       392364.025  MultiPolygon
# 10            Wild            Spring        80833.444  MultiPolygon
# 11      Plantation            Summer       362344.028  MultiPolygon
# 12      Plantation            Summer       310482.150  MultiPolygon
# 13            Wild            Winter       188652.916  MultiPolygon
# 14            Wild              Fall       115634.572  MultiPolygon
# 15            Wild            Spring       164451.725  MultiPolygon
# 16            Wild            Summer       335812.855  MultiPolygon
# 17      Plantation            Spring       308161.086  MultiPolygon
# 18            Wild            Winter       315315.628  MultiPolygon
# 19            Wild            Summer       320881.408  MultiPolygon
# 20            Wild            Spring       143605.244  MultiPolygon
# 21            Wild            Summer        69014.432  MultiPolygon
# 22      Plantation            Spring       217784.142  MultiPolygon
# 23      Plantation              Fall        69349.863  MultiPolygon
# 24      Plantation            Spring       350605.987  MultiPolygon
#
#                                  geometry.coordinates
# 0   [[[[-117.68286416250682, 33.87223450781116], [...
# 1   [[[[-119.50857432459836, 34.87043932367128], [...
# 2   [[[[-118.50266751919736, 34.69779051559962], [...
# 3                      [[[[-120.239271, 33.427726]]]]
# 4                      [[[[-116.766138, 36.991884]]]]
# 5                      [[[[-114.178944, 39.939574]]]]
# 6                      [[[[-124.305992, 33.109137]]]]
# 7                      [[[[-122.467949, 32.066115]]]]
# 8                      [[[[-115.509535, 33.148633]]]]
# 9                      [[[[-118.566216, 32.915909]]]]
# 10                     [[[[-123.015123, 39.522466]]]]
# 11                     [[[[-113.146194, 36.667442]]]]
# 12                       [[[[-113.077019, 36.6491]]]]
# 13                       [[[[-119.271273, 38.8901]]]]
# 14                      [[[[-123.904673, 33.59096]]]]
# 15                     [[[[-123.674361, 32.723241]]]]
# 16                     [[[[-122.000931, 34.083983]]]]
# 17                     [[[[-122.327311, 38.051851]]]]
# 18                     [[[[-117.773013, 38.775689]]]]
# 19                     [[[[-110.749748, 37.047721]]]]
# 20                       [[[[-113.9242, 33.506431]]]]
# 21                     [[[[-111.248967, 32.790139]]]]
# 22                     [[[[-115.348461, 32.265092]]]]
# 23                     [[[[-118.083507, 33.900367]]]]
# 24                     [[[[-112.590177, 38.507874]]]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  150 non-null    object
#  1   properties.id         147 non-null    float64
#  2   properties.Site       150 non-null    object
#  3   properties.Type       150 non-null    object
#  4   properties.Season     150 non-null    object
#  5   properties.Area       150 non-null    float64
#  6   geometry.type         150 non-null    object
#  7   geometry.coordinates  150 non-null    object
# dtypes: float64(2), object(6)
# memory usage: 9.5+ KB

# %%
df = df.drop(columns=["properties.id"])
df.head()
# Out:
#       type                           properties.Site properties.Type  \
# 0  Feature                               Chino Hills            Wild
# 1  Feature           Carrizo Plain National Monument            Wild
# 2  Feature  Antelope Valley California Poppy Reserve            Wild
# 3  Feature                               Red Hills 0      Plantation
# 4  Feature                           Golden Valley 1            Wild
#
#   properties.Season  properties.Area geometry.type  \
# 0            Spring        25382.057  MultiPolygon
# 1            Spring       354751.514  MultiPolygon
# 2            Spring        25182.333  MultiPolygon
# 3            Summer        14874.759  MultiPolygon
# 4            Winter       364929.893  MultiPolygon
#
#                                 geometry.coordinates
# 0  [[[[-117.68286416250682, 33.87223450781116], [...
# 1  [[[[-119.50857432459836, 34.87043932367128], [...
# 2  [[[[-118.50266751919736, 34.69779051559962], [...
# 3                     [[[[-120.239271, 33.427726]]]]
# 4                     [[[[-116.766138, 36.991884]]]]

# %%
df = df.drop(columns=["type"])

# %%
df = df.rename(columns={
    "properties.Site": "Site",
    "properties.Type": "Type",
    "properties.Season": "Season",
    "properties.Area": "Area",
    "geometry.type": "GeometryType",
    "geometry.coordinates": "Coordinates"
})

# %%
df['Site'] = df['Site'].str.replace(r'\s*\d+$', '', regex=True)

# %%
df.head(25)
# Out:
#                                         Site        Type  Season        Area  \
# 0                                Chino Hills        Wild  Spring   25382.057
# 1            Carrizo Plain National Monument        Wild  Spring  354751.514
# 2   Antelope Valley California Poppy Reserve        Wild  Spring   25182.333
# 3                                  Red Hills  Plantation  Summer   14874.759
# 4                              Golden Valley        Wild  Winter  364929.893
# 5                                Bear Valley        Wild  Winter  228192.230
# 6                              Golden Valley  Plantation    Fall  170488.528
# 7                              Golden Valley  Plantation  Spring  379094.253
# 8                              Laura Reserve        Wild    Fall  149813.089
# 9                                Bear Valley  Plantation  Winter  392364.025
# 10                            Carlsbad Ranch        Wild  Spring   80833.444
# 11                             Laura Reserve  Plantation  Summer  362344.028
# 12                               Bear Valley  Plantation  Summer  310482.150
# 13                          Sedgwick Reserve        Wild  Winter  188652.916
# 14                            Carlsbad Ranch        Wild    Fall  115634.572
# 15                             Golden Valley        Wild  Spring  164451.725
# 16                             Golden Valley        Wild  Summer  335812.855
# 17                          Sedgwick Reserve  Plantation  Spring  308161.086
# 18                             Golden Valley        Wild  Winter  315315.628
# 19                             Laura Reserve        Wild  Summer  320881.408
# 20                             Laura Reserve        Wild  Spring  143605.244
# 21                               Bear Valley        Wild  Summer   69014.432
# 22                            Carlsbad Ranch  Plantation  Spring  217784.142
# 23                             Golden Valley  Plantation    Fall   69349.863
# 24                             Golden Valley  Plantation  Spring  350605.987
#
#     GeometryType                                        Coordinates
# 0   MultiPolygon  [[[[-117.68286416250682, 33.87223450781116], [...
# 1   MultiPolygon  [[[[-119.50857432459836, 34.87043932367128], [...
# 2   MultiPolygon  [[[[-118.50266751919736, 34.69779051559962], [...
# 3   MultiPolygon                     [[[[-120.239271, 33.427726]]]]
# 4   MultiPolygon                     [[[[-116.766138, 36.991884]]]]
# 5   MultiPolygon                     [[[[-114.178944, 39.939574]]]]
# 6   MultiPolygon                     [[[[-124.305992, 33.109137]]]]
# 7   MultiPolygon                     [[[[-122.467949, 32.066115]]]]
# 8   MultiPolygon                     [[[[-115.509535, 33.148633]]]]
# 9   MultiPolygon                     [[[[-118.566216, 32.915909]]]]
# 10  MultiPolygon                     [[[[-123.015123, 39.522466]]]]
# 11  MultiPolygon                     [[[[-113.146194, 36.667442]]]]
# 12  MultiPolygon                       [[[[-113.077019, 36.6491]]]]
# 13  MultiPolygon                       [[[[-119.271273, 38.8901]]]]
# 14  MultiPolygon                      [[[[-123.904673, 33.59096]]]]
# 15  MultiPolygon                     [[[[-123.674361, 32.723241]]]]
# 16  MultiPolygon                     [[[[-122.000931, 34.083983]]]]
# 17  MultiPolygon                     [[[[-122.327311, 38.051851]]]]
# 18  MultiPolygon                     [[[[-117.773013, 38.775689]]]]
# 19  MultiPolygon                     [[[[-110.749748, 37.047721]]]]
# 20  MultiPolygon                       [[[[-113.9242, 33.506431]]]]
# 21  MultiPolygon                     [[[[-111.248967, 32.790139]]]]
# 22  MultiPolygon                     [[[[-115.348461, 32.265092]]]]
# 23  MultiPolygon                     [[[[-118.083507, 33.900367]]]]
# 24  MultiPolygon                     [[[[-112.590177, 38.507874]]]]

# %%
df.to_csv("flowerBlooms_Clean.csv", index=False)

# %%
df.head()
# Out:
#                                        Site        Type  Season        Area  \
# 0                               Chino Hills        Wild  Spring   25382.057
# 1           Carrizo Plain National Monument        Wild  Spring  354751.514
# 2  Antelope Valley California Poppy Reserve        Wild  Spring   25182.333
# 3                                 Red Hills  Plantation  Summer   14874.759
# 4                             Golden Valley        Wild  Winter  364929.893
#
#    GeometryType                                        Coordinates
# 0  MultiPolygon  [[[[-117.68286416250682, 33.87223450781116], [...
# 1  MultiPolygon  [[[[-119.50857432459836, 34.87043932367128], [...
# 2  MultiPolygon  [[[[-118.50266751919736, 34.69779051559962], [...
# 3  MultiPolygon                     [[[[-120.239271, 33.427726]]]]
# 4  MultiPolygon                     [[[[-116.766138, 36.991884]]]]
